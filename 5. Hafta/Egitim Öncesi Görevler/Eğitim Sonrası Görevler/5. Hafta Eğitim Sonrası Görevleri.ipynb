# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
hiz= float(input("Hız giriniz:"))
ivme= float(input("İvme giriniz:"))
zaman= float(input("Süre giriniz:"))
def sonHiz(hiz, ivme, zaman):
    finalvelocity=float(hiz*ivme*zaman)
    print("Son hız:",finalvelocity)
sonHiz(hiz,ivme,zaman)
# Out:
# Son hız: 264.0

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mukemmelsayi(num):
    toplam=0
    for i in  range(1,num):
        if num%i==0:
            toplam+=i
    return toplam==num
for i in range(1,1000):
    if mukemmelsayi(i):
        print(i, "mükemmel sayıdır.")
# Out:
# 6 mükemmel sayıdır.
# 28 mükemmel sayıdır.
# 496 mükemmel sayıdır.

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisagor():
    a=int(input("Kenar uzunluğu giriniz:"))
    b=int(input("Kenar uzunluğu giriniz:"))
    c=int(input("Kenar uzunluğu giriniz:"))
    if c**2==a**2+b**2:
        print("Dik üçgendir.")
    else:
        print("Dik üçgen değildir.")
pisagor()
# Out:
# Dik üçgendir.

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math
def duvar(yükseklik, genişlik, kaplama):
   alan=yükseklik*genişlik
   kutuSayisi=math.ceil(alan/kaplama)
   print(f"{kutuSayisi} kutu boyaya ihtiyacımız var.")

yükseklik=float(input("Yükseklik?"))
genişlik=float(input("Genişlik?"))
kaplama=5
duvar(yükseklik,genişlik,kaplama)
# Out:
# 2 kutu boyaya ihtiyacımız var.

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
def count(kelime):
    unlu=0
    unsuz=0
    for i in range(len(kelime)):
        if kelime[i] in ['a','e','o','ö','i','ı','u','ü']:
            unlu+=1
        else:
            unsuz+=1
    print("Ünlü harf sayısı:", unlu)
    print("Ünsüz harf sayısı:", unsuz)
x=input("Ünlü ve ünsüz harf sayısını için bir kelime giriniz:").lower()
count(x)
# Out:
# Ünlü harf sayısı: 3
# Ünsüz harf sayısı: 5

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def is_even_num(1):
    enum=[]
    for n in 1:
        if n%2==0:
            enum.append(n)
    return enum
print(is_even_num([1,2,3,4,5,6,7,8,9]))
# Out:
#   Cell In[17], line 1
#     def is_even_num(1):
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def addition(num):
    if num:
        return num + addition(num-1)
    else:
        return 0
print(addition(10))
# Out:
# 55
